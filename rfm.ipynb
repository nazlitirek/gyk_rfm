# %%
import pandas as pd

# %%
df = pd.read_excel('Online Retail.xlsx')

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.isnull().sum()
df.dropna(inplace=True)
df.shape
# Out:
# (406829, 8)

# %%
df = df[df['Country'] == 'United Kingdom']
df.shape
# Out:
# (361878, 8)

# %%
df.head(3)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom

# %%
df['TotalPrice'] = df['Quantity'] * df['UnitPrice']
df.head(3)
# Out:
#   InvoiceNo StockCode                         Description  Quantity  \
# 0    536365    85123A  WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                 WHITE METAL LANTERN         6
# 2    536365    84406B      CREAM CUPID HEARTS COAT HANGER         8
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom       22.00

# %%
# RFM Hesaplama
import datetime as dt
analysis_date = df['InvoiceDate'].max() + dt.timedelta(days=1)
analysis_date
# Out:
# Timestamp('2011-12-10 12:49:00')

# %%
rfm = df.groupby("CustomerID").agg({
    "InvoiceDate": lambda x: (analysis_date - x.max()).days,
    "InvoiceNo": "nunique",
    "TotalPrice": "sum"
})
#sum,mean,max,min
rfm.columns = ["Recency","Frequency","Monetary"]
#rfm

# %%
rfm["R_Score"] = pd.qcut(rfm["Recency"], 5, labels=[5,4,3,2,1], duplicates='drop')
rfm["F_Score"] = pd.qcut(rfm["Frequency"].rank(method="first"), 5, labels=[1,2,3,4,5])
rfm["M_Score"] = pd.qcut(rfm["Monetary"].rank(method="first"), 5, labels=[1,2,3,4,5])
rfm["RFM_Score"] = rfm["R_Score"].astype(str) + rfm["F_Score"].astype(str) + rfm["M_Score"].astype(str)
rfm
# Out:
#             Recency  Frequency  Monetary R_Score F_Score M_Score RFM_Score
# CustomerID
# 12346.0         326          2      0.00       1       2       1       121
# 12747.0           2         11   4196.01       5       5       5       555
# 12748.0           1        224  29072.10       5       5       5       555
# 12749.0           4          8   3868.20       5       5       5       555
# 12820.0           3          4    942.34       5       3       4       534
# ...             ...        ...       ...     ...     ...     ...       ...
# 18280.0         278          1    180.60       1       2       1       121
# 18281.0         181          1     80.82       1       2       1       121
# 18282.0           8          3    176.60       5       3       1       531
# 18283.0           4         16   2094.88       5       5       5       555
# 18287.0          43          3   1837.28       3       3       4       334
#
# [3950 rows x 7 columns]

# %%
from sklearn.cluster import KMeans

# %%
X = rfm[["Recency","Frequency","Monetary"]]
X
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 12346.0         326          2      0.00
# 12747.0           2         11   4196.01
# 12748.0           1        224  29072.10
# 12749.0           4          8   3868.20
# 12820.0           3          4    942.34
# ...             ...        ...       ...
# 18280.0         278          1    180.60
# 18281.0         181          1     80.82
# 18282.0           8          3    176.60
# 18283.0           4         16   2094.88
# 18287.0          43          3   1837.28
#
# [3950 rows x 3 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
kmeans = KMeans(n_clusters=5,random_state=42) # elbow method kullan!
rfm["KMeansCluster"] = kmeans.fit_predict(X_scaled)
# Out:
# Exception in thread Thread-35 (_readerthread):
# Traceback (most recent call last):
#   File "c:\Users\tirek\anaconda3\envs\ML\Lib\threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "C:\Users\tirek\AppData\Roaming\Python\Python312\site-packages\ipykernel\ipkernel.py", line 761, in run_closure
#     _threading_Thread_run(self)
#   File "c:\Users\tirek\anaconda3\envs\ML\Lib\threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "c:\Users\tirek\anaconda3\envs\ML\Lib\subprocess.py", line 1599, in _readerthread
#     buffer.append(fh.read())
#                   ^^^^^^^^^
#   File "<frozen codecs>", line 322, in decode
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xd5 in position 28: invalid continuation byte
# c:\Users\tirek\anaconda3\envs\ML\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# 'NoneType' object has no attribute 'splitlines'
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "c:\Users\tirek\anaconda3\envs\ML\Lib\site-packages\joblib\externals\loky\backend\context.py", line 262, in _count_physical_cores
#     cpu_info = cpu_info.stdout.splitlines()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^

# %%
rfm
# Out:
#             Recency  Frequency  Monetary R_Score F_Score M_Score RFM_Score  \
# CustomerID
# 12346.0         326          2      0.00       1       2       1       121
# 12747.0           2         11   4196.01       5       5       5       555
# 12748.0           1        224  29072.10       5       5       5       555
# 12749.0           4          8   3868.20       5       5       5       555
# 12820.0           3          4    942.34       5       3       4       534
# ...             ...        ...       ...     ...     ...     ...       ...
# 18280.0         278          1    180.60       1       2       1       121
# 18281.0         181          1     80.82       1       2       1       121
# 18282.0           8          3    176.60       5       3       1       531
# 18283.0           4         16   2094.88       5       5       5       555
# 18287.0          43          3   1837.28       3       3       4       334
#
#             KMeansCluster
# CustomerID
# 12346.0                 0
# 12747.0                 1
# 12748.0                 2
# 12749.0                 1
# 12820.0                 1
# ...                   ...
# 18280.0                 0
# 18281.0                 0
# 18282.0                 1
# 18283.0                 1
# 18287.0                 1
#
# [3950 rows x 8 columns]

# %%
# Elbow method ile best n_cluster bulma
# Scatter plot oluşturma (kaç grup var? kaç eleamn var?)

rfm[rfm["KMeansCluster"] == 0]
# Out:
#             Recency  Frequency  Monetary R_Score F_Score M_Score RFM_Score  \
# CustomerID
# 12346.0         326          2      0.00       1       2       1       121
# 12821.0         214          1     92.72       1       1       1       111
# 12829.0         322          3    253.05       1       3       2       132
# 12831.0         262          1    215.05       1       1       1       111
# 12833.0         145          1    417.38       2       1       2       212
# ...             ...        ...       ...     ...     ...     ...       ...
# 18260.0         173          8   2595.00       2       5       5       255
# 18262.0         140          1    149.48       2       2       1       221
# 18269.0         358          2    138.90       1       3       1       131
# 18280.0         278          1    180.60       1       2       1       121
# 18281.0         181          1     80.82       1       2       1       121
#
#             KMeansCluster
# CustomerID
# 12346.0                 0
# 12821.0                 0
# 12829.0                 0
# 12831.0                 0
# 12833.0                 0
# ...                   ...
# 18260.0                 0
# 18262.0                 0
# 18269.0                 0
# 18280.0                 0
# 18281.0                 0
#
# [989 rows x 8 columns]

# %%
# FAST API ile bu modeli api haline getirelim. 
# Yeni bir müşterinin (RFM değeri hesaplanmış olsun.) RFM değerleri verildiğinde müşterinin dahil oldugu grubu 
# tahmin eden bir endpoint yazalım.
# Arayüz (Opsiyonel)

# %%
import pickle

with open('kmeans_model.pkl', 'wb') as file:
    pickle.dump(kmeans, file)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import pickle
#       3 with open('kmeansmodel.pkl', 'wb') as file:
# ----> 4     pickle.dump(kmeans, file)
#
# NameError: name 'kmeans' is not defined
